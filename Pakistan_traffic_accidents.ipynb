# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Pakistani_Traffic_Accidents.csv')

# %%
df
# Out:
#    *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                     NaN        NaN                        NaN
# 1                     NaN       Year  Total number of accidents
# 2                Pakistan    2008-09                       9496
# 3                Pakistan    2009-10                       9747
# 4                Pakistan    2010-11                       9723
# ..                    ...        ...                        ...
# 59              Islamabad    2014-15                        216
# 60              Islamabad    2015-16                        244
# 61              Islamabad    2016-17                        226
# 62              Islamabad    2017-18                        259
# 63              Islamabad    2018-19                        238
#
#          Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0               NaN                  NaN        NaN        NaN
# 1   Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# ...

# %%
# storing the data in another data frame , in case I do some unwanted changings
df1 = pd.DataFrame(df)

# %%
# deleting the first row as it contain NaN values
df = df.drop(df.index[0])
df = df.reset_index(drop=True)

# %%
# the first row contains column names
col_names = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns = col_names  
df = df.reset_index(drop=True)

# %%
df
# Out:
# 0         NaN        Year Total number of accidents Fatal Accidents  \
# 0    Pakistan     2008-09                      9496            4145
# 1    Pakistan     2009-10                      9747            4378
# 2    Pakistan     2010-11                      9723            4280
# 3    Pakistan     2011-12                      9140            3966
# 4    Pakistan  2012-13 *                       8988            3884
# ..        ...         ...                       ...             ...
# 57  Islamabad     2014-15                       216             107
# 58  Islamabad     2015-16                       244             120
# 59  Islamabad     2016-17                       226             127
# 60  Islamabad     2017-18                       259             157
# 61  Islamabad     2018-19                       238             127
#
# 0  Non-Fatal Accidents Killed Injured Total number of vehicles involved
# 0                 5351   4907   11037                             10322
# ...

# %%
# setting the notebook to print all the rows
pd.set_option('display.max_rows',None)

# %%
df
# Out:
# 0                  NaN        Year Total number of accidents Fatal Accidents  \
# 0             Pakistan     2008-09                      9496            4145
# 1             Pakistan     2009-10                      9747            4378
# 2             Pakistan     2010-11                      9723            4280
# 3             Pakistan     2011-12                      9140            3966
# 4             Pakistan  2012-13 *                       8988            3884
# 5             Pakistan    2013-14*                      8359            3500
# 6             Pakistan    2014-15*                      7865            3214
# 7             Pakistan    2015-16*                      9100            3591
# 8             Pakistan    2016-17*                      9582            4036
# 9             Pakistan     2017-18                     11121            4829
# 10            Pakistan     2018-19                     10779            4878
# ...

# %%
# extracting only the country data into a separate data frame
whole_country_data = df.iloc[:11]
whole_country_data.reset_index(drop=True, inplace=True)

# %%
# from row 11 to 55 it contain the provincial data, so storing it in a separate data frame
provincial_data = df.iloc[11:55]
provincial_data.reset_index(drop=True, inplace=True)
# setting the column name to "Province"
provincial_data.rename(columns={np.nan: 'Province'}, inplace=True)

# %%
# the remaining data is for islamabad so storing it separately
islamabad_data =  df.iloc[55:]
islamabad_data.reset_index(drop=True, inplace=True)

# %%
whole_country_data
# Out:
# 0        NaN        Year Total number of accidents Fatal Accidents  \
# 0   Pakistan     2008-09                      9496            4145
# 1   Pakistan     2009-10                      9747            4378
# 2   Pakistan     2010-11                      9723            4280
# 3   Pakistan     2011-12                      9140            3966
# 4   Pakistan  2012-13 *                       8988            3884
# 5   Pakistan    2013-14*                      8359            3500
# 6   Pakistan    2014-15*                      7865            3214
# 7   Pakistan    2015-16*                      9100            3591
# 8   Pakistan    2016-17*                      9582            4036
# 9   Pakistan     2017-18                     11121            4829
# 10  Pakistan     2018-19                     10779            4878
#
# 0  Non-Fatal Accidents Killed Injured Total number of vehicles involved
# 0                 5351   4907   11037                             10322
# ...

# %%
provincial_data
# Out:
# 0             Province      Year Total number of accidents Fatal Accidents  \
# 0               Punjab   2008-09                      5240            2471
# 1               Punjab   2009-10                      5344            2590
# 2               Punjab   2010-11                      5420            2591
# 3               Punjab   2011-12                      4990            2361
# 4               Punjab  2012-13                       4587            2213
# 5               Punjab   2013-14                      3696            1717
# 6               Punjab   2014-15                      3054            1435
# 7               Punjab   2015-16                      3288            1576
# 8               Punjab   2016-17                      3819            1989
# 9               Punjab   2017-18                      5093            2708
# 10              Punjab   2018-19                      4823            2808
# ...

# %%
islamabad_data
# Out:
# 0        NaN      Year Total number of accidents Fatal Accidents  \
# 0  Islamabad  2012-13                        201             107
# 1  Islamabad   2013-14                       256             120
# 2  Islamabad   2014-15                       216             107
# 3  Islamabad   2015-16                       244             120
# 4  Islamabad   2016-17                       226             127
# 5  Islamabad   2017-18                       259             157
# 6  Islamabad   2018-19                       238             127
#
# 0 Non-Fatal Accidents Killed Injured Total number of vehicles involved
# 0                  94    109     180                               212
# 1                 136    132     206                               256
# 2                 109    118     182                               217
# 3                 124    140     209                               244
# 4                  99    129     124                               216
# ...

# %% [markdown]
# ### In which  province the most accidents have occured?

# %%
provincial_data['Total number of accidents'].dtype
# Out:
# dtype('O')

# %%
# converting the data type from object to numeric for mathematical operations
provincial_data['Total number of accidents'] = pd.to_numeric(provincial_data['Total number of accidents'], errors='coerce')

# %%
# grouping the data by each province and adding total accidents accross all the years
province_total_accidents = provincial_data.groupby('Province')['Total number of accidents'].sum()

# %%
# finding the province with the highest total number of accidents, it will give the province name
province_with_most_accidents = province_total_accidents.idxmax()

# %%
# it will give the actual count "no of accidents"
most_accidents_count = province_total_accidents.max()

# %%
print(f"The province with the most accidents is {province_with_most_accidents} with {most_accidents_count} accidents.")
# Out:
# The province with the most accidents is Punjab with 49354 accidents.

# %% [markdown]
# ### In which province the least accidents have accured?

# %%
# finding the province with the least total number of accidents
province_with_least_accidents = province_total_accidents.idxmin()

# %%
least_accidents_count = province_total_accidents.min()

# %%
print(f"The province with the least accidents is {province_with_least_accidents} with {least_accidents_count} accidents.")
# Out:
# The province with the least accidents is Balochistan with 4062 accidents.

# %% [markdown]
# ### In which province most people were killed?

# %%
# converting the data type from object to numeric for mathematical operations
provincial_data['Killed'] = pd.to_numeric(provincial_data['Killed'], errors='coerce')

# %%
# grouping by province and summing the "total number of people killed" for each province across all years
province_total_killed = provincial_data.groupby('Province')['Killed'].sum()

# %%
# finding the province with the most people killed, it will give the province name
province_with_most_killed = province_total_killed.idxmax()

# %%
# it will give the count "total people killed"
most_killed_count = province_total_killed.max()

# %%
print(f"The province with the most people killed is {province_with_most_killed} with {most_killed_count} fatalities.")
# Out:
# The province with the most people killed is Punjab with 29978 fatalities.

# %% [markdown]
# ### In which province least people were killed?

# %%
province_with_least_killed = province_total_killed.idxmin()

# %%
least_killed_count = province_total_killed.min()

# %%
print(f"The province with the least people killed is {province_with_least_killed} with {least_killed_count} fatalities.")
# Out:
# The province with the least people killed is Balochistan with 2604 fatalities.

# %% [markdown]
# ### In which province most people were injured?

# %%
provincial_data['Injured'] = pd.to_numeric(provincial_data['Injured'], errors='coerce')

# %%
province_total_injured = provincial_data.groupby('Province')['Injured'].sum()

# %%
province_with_most_injured = province_total_injured.idxmax()

# %%
most_injured_count = province_total_injured.max()

# %%
print(f"The province with the most people injured is {province_with_most_injured} with {most_injured_count} injured people.")
# Out:
# The province with the most people injured is Punjab with 57103 injured people.

# %% [markdown]
# ### In which province least people were injured?

# %%
province_with_least_injured = province_total_injured.idxmin()

# %%
least_injured_count = province_total_injured.min()

# %%
print(f"The province with the least people injured is {province_with_least_injured} with {least_injured_count} injured people.")
# Out:
# The province with the least people injured is Balochistan with 5592 injured people.

# %% [markdown]
# ### In which year most accident has occurred?

# %%
whole_country_data['Total number of accidents'] = pd.to_numeric(whole_country_data['Total number of accidents'], errors='coerce')

# %%
year_with_most_accidents = whole_country_data.loc[whole_country_data['Total number of accidents'].idxmax(), 'Year']

# %%
print(f"The year with the most accidents is {year_with_most_accidents}.")
# Out:
# The year with the most accidents is 2017-18.

# %% [markdown]
# ### In which year least accident has occurred?

# %%
year_with_least_accidents = whole_country_data.loc[whole_country_data['Total number of accidents'].idxmin(), 'Year']

# %%
print(f"The year with the least accidents is {year_with_least_accidents}.")
# Out:
# The year with the least accidents is 2014-15*.

# %% [markdown]
# ## Bonus Questions

# %% [markdown]
# ### Visualizing how the total number of accidents have changed the over the years.

# %%
# getting th Year and total no of accidents columns
years = whole_country_data['Year']
accidents = whole_country_data['Total number of accidents']

# %%
# creating a line plot to visualize the trend of total accidents over the years
plt.figure(figsize=(10, 6))
plt.plot(years, accidents, marker='o', color='b', linestyle='-')
plt.title('Total Number of Accidents Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Number of Accidents')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Accident Statistics Comparison Across Provinces

# %%
# grouping by province
province_grouped = provincial_data.groupby('Province')

# %%
# getting the stats , it will contain all these columns but all summed up for the total years
province_stats = province_grouped[['Total number of accidents', 'Total number of vehicles involved', 'Killed', 'Injured']].sum()

# %%
# creating a grouped bar plot
province_stats.plot(kind='bar', figsize=(12, 8))
plt.title('Accident Statistics by Province')
plt.xlabel('Province')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trend Comparison: Fatal vs. Non-Fatal Accidents Over Time

# %%
years = whole_country_data['Year']
fatal_accidents = whole_country_data['Fatal Accidents']
non_fatal_accidents = whole_country_data['Non-Fatal Accidents']
total_vehicles_involved = whole_country_data['Total number of vehicles involved']

# %%
# creating sub-plots
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# for fatal Vs non-fatal accidents
axes[0].plot(years, fatal_accidents, marker='o', label='Fatal Accidents', color='red')
axes[0].plot(years, non_fatal_accidents, marker='o', label='Non-Fatal Accidents', color='blue')
axes[0].set_title('Fatal vs. Non-Fatal Accidents Over the Years')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Number of Accidents')
axes[0].legend()
axes[0].grid(True)

# plotting for total accidents involved
axes[1].plot(years, total_vehicles_involved, marker='o', color='green')
axes[1].set_title('Total Vehicles Involved in Accidents Over the Years')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Total Vehicles Involved')
axes[1].grid(True)
